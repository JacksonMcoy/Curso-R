# %%
library("neuralnet", lib.loc="~/R/x86_64-pc-linux-gnu-library/3.3")
library("grid", lib.loc="/usr/lib/R/library")
library("MASS", lib.loc="/usr/lib/R/library")

# %% [markdown]
# # Aprendizaje Supervisado

# %% [markdown]
# ## Perceptrón Simple

# %%
or = read.csv("OR.csv")
or
or$x1 = c(or$z==1)
or$x0 = c(or$z==0)
or$z = NULL
or
# Out:
#   x y z
# 1 1 1 1
# 2 1 0 1
# 3 0 1 1
# 4 0 0 0
#   x y    x1    x0
# 1 1 1  TRUE FALSE
# 2 1 0  TRUE FALSE
# 3 0 1  TRUE FALSE
# 4 0 0 FALSE  TRUE

# %%
inet <- neuralnet(x1 + x0 ~ x + y, or, hidden=1, lifesign="full")
plot(inet,rep="best")
# Out:
# hidden: 1    thresh: 0.01    rep: 1/1    steps:     110	error: 0.00016	time: 0.05 secs
# plot without title

# %%
and = read.csv("AND.csv")
and
and$x1 = c(and$z==1)
and$x0 = c(and$z==0)
and$z = NULL
and
# Out:
#   x y z
# 1 1 1 1
# 2 1 0 0
# 3 0 1 0
# 4 0 0 0
#   x y    x1    x0
# 1 1 1  TRUE FALSE
# 2 1 0 FALSE  TRUE
# 3 0 1 FALSE  TRUE
# 4 0 0 FALSE  TRUE

# %%
inet <- neuralnet(x1 + x0 ~ x + y, and, hidden=1, lifesign="full")
plot(inet,rep="best")
# Out:
# hidden: 1    thresh: 0.01    rep: 1/1    steps:     291	error: 0.0159 	time: 0.09 secs
# plot without title

# %% [markdown]
# ## Perceptrón Multicapa

# %%
xor = read.csv("XOR.csv")
xor
xor$x1 = c(xor$z==1)
xor$x0 = c(xor$z==0)
xor$z = NULL
xor
# Out:
#   x y z
# 1 1 1 0
# 2 1 0 1
# 3 0 1 1
# 4 0 0 0
#   x y    x1    x0
# 1 1 1 FALSE  TRUE
# 2 1 0  TRUE FALSE
# 3 0 1  TRUE FALSE
# 4 0 0 FALSE  TRUE

# %%
inet <- neuralnet(x1 + x0 ~ x + y, xor, hidden=2, lifesign="full")
plot(inet,rep="best")
# Out:
# hidden: 2    thresh: 0.01    rep: 1/1    steps:      34	error: 0.99788	time: 0.01 secs
# plot without title

# %% [markdown]
# ## Eligiendo la base de datos IRIS

# %%
# De las 150 linea elije 100 columnas aleatorias
itrain <- iris[sample(1:150,100),]
itrain $ setosa<- c( itrain $Species =='setosa')
itrain $ versicolor <- c( itrain $Species =='versicolor')
itrain $ virginica <- c( itrain $Species == 'virginica')

# %%
itrain
itrain $ Species <- NULL
itrain
# Out:
#     Sepal.Length Sepal.Width Petal.Length Petal.Width    Species setosa
# 137          6.3         3.4          5.6         2.4  virginica  FALSE
# 112          6.4         2.7          5.3         1.9  virginica  FALSE
# 119          7.7         2.6          6.9         2.3  virginica  FALSE
# 41           5.0         3.5          1.3         0.3     setosa   TRUE
# 111          6.5         3.2          5.1         2.0  virginica  FALSE
# 98           6.2         2.9          4.3         1.3 versicolor  FALSE
# 102          5.8         2.7          5.1         1.9  virginica  FALSE
# 42           4.5         2.3          1.3         0.3     setosa   TRUE
# 79           6.0         2.9          4.5         1.5 versicolor  FALSE
# 18           5.1         3.5          1.4         0.3     setosa   TRUE
# 83           5.8         2.7          3.9         1.2 versicolor  FALSE
# 141          6.7         3.1          5.6         2.4  virginica  FALSE
# ...

# %%
inet <- neuralnet(setosa + versicolor + virginica ~ Sepal.Length + Sepal.Width + Petal.Length + Petal.Width, itrain, hidden=3, lifesign="full")
# Out:
# hidden: 3    thresh: 0.01    rep: 1/1    steps:    1000	min thresh: 0.3829293245
#                                                    2000	min thresh: 0.2125124412
#                                                    3000	min thresh: 0.1493098387
#                                                    4000	min thresh: 0.1070472188
#                                                    5000	min thresh: 0.0454445466
#                                                    6000	min thresh: 0.02574248699
#                                                    7000	min thresh: 0.02420750915
#                                                    8000	min thresh: 0.02134600573
#                                                    9000	min thresh: 0.02134600573
#                                                   10000	min thresh: 0.02102984822
#                                                   11000	min thresh: 0.01933520085
# ...

# %%
plot(inet, rep="best")
# Out:
# plot without title

# %%
predict <- compute(inet, iris[1:4])
#predict

# %%
which.max(predict$net.result[1,])
# Out:
# [1] 1

# %%
result<-0
for (i in 1:150) { result[i] <- which.max(predict$net.result[i,]) }

# %%
for (i in 1:150) { if (result[i]==1) {result[i] = "setosa"}}
for (i in 1:150) { if (result[i]==2) {result[i] = "versicolor"} }
for (i in 1:150) { if (result[i]==3) {result[i] = "virginica"} }

# %%
comparison <- iris
comparison$Predicted <- result
comparison

# %% [markdown]
# # Aprendizaje NO Supervisado

# %%
library("kohonen", lib.loc="~/R/x86_64-pc-linux-gnu-library/3.3")
library(kohonen)
i = iris
set.seed(7)
i$Species=NULL
i.sc = scale(i)
i.som = som(data = i.sc,grid = somgrid(5,5,topo = "hexagonal"))

# %% [markdown]
# * Ploteo - type = "codes"
#
# Utilizando la funcion ploteo con el parametro type = "codes". No muestra la agrupacion de datos de acuerdo a sus cacteristicas, indicando cuales son estas que los indentifica a cada grupo. Además se puede observar la semejanza que existe en la interseccion de cada grupos, pareciendose a cada grupo de las intersecta.

# %%
plot(i.som,main = "Datos de la tabla iris",type="codes")
# Out:
# Plot with title “Datos de la tabla iris”

# %% [markdown]
# * Ploteo - type = "changes"
#
# Utilizando la función ploteo con el parametro type = "changes". Muestra la distancia media al conjunto de elementos mas cercano, el cual cuanto mas pequeño es esta media nos quiere decir que un elemento se encuentra cerca de otros elementos que poseen caracteristicas en común.

# %%
plot(i.som,main = "Datos de la tabla iris",type="changes")
# Out:
# Plot with title “Datos de la tabla iris”

# %% [markdown]
# * Ploteo - type = "counts"
#
# Utilizando la funcion ploteo con el paramentro type = "counts". Nos indica la cantidad de elementos que se encuentra en cada uno de los grupos. Si bien es cierto se podria preferir un distribucion uniforme para cada tamaño que se asigne a la malla pero no es asi, dependiendo del tamaño de la malla se visualizara la existencia de grupos vacios, para evitar esto es necesario disminuir la dimension de la malla. Por lo contrario si casi todos los grupos posee la maxima cantidad de elementos, para una mejor visualizacion es necesario aumentar la dimension de la malla.

# %%
plot(i.som,main = "Datos de la tabla iris",type="counts")
# Out:
# plot without title

# %% [markdown]
# * Ploteo - type = "dist.neighbours"
#
# Utilizando la funcion ploteo con el paramentro type = "dist.neighbours".Nos ayuda a identificar una mayor agrupación. El cual nos soluciona el problema que se tenia anteriormente. Y debido a la mayor distribución se observa una disminución en la maxima cantidad que puede haber en un grupo.

# %%
plot(i.som,main = "Datos de la tabla iris",type="dist.neighbours")
# Out:
# plot without title
